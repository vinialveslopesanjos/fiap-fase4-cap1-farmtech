# %% [markdown]
# # FarmTech - Analise para o video
#
# Notebook de apoio com os graficos essenciais da entrega: metricas, correlacao, dispersao e tendencias.

# %%
import pandas as pd
df = pd.read_csv('data/leituras_sensores.csv', parse_dates=['data_hora'])
df.head()

# %% [markdown]
# ## Metricas do modelo
#
# Use esta tabela para comentar MAE, MSE, RMSE e R2.

# %%
metricas_por_alvo
# Out:
# Tabela de metricas do modelo

# %% [markdown]
# ## Correlacao
#
# Mostra a relacao entre sensores, rendimento e recomendacoes.

# %%
matriz_correlacao

# %% [markdown]
# ## Umidade x rendimento
#
# Grafico simples para explicar como a umidade influencia a produtividade.

# %%
dispersao_umidade_rendimento

# %% [markdown]
# ## Tendencias
#
# Resumo diario de rendimento, irrigacao e fertilizacao.

# %%
tendencias_diarias
